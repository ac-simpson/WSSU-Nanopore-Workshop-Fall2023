# %% [markdown]
# # Filtering Nanopore data and assigning taxonomy to reads using Epi2Me
#
# There are a variety of tools that can be used to filter out bad quality Nanopore reads and reads with unsuitable lengths, and to match reads to their most likely species. However, we're going to focus on a very easy set of tools to use: [Epi2me labs](https://labs.epi2me.io). This is a Nanopore bioinformatics workbench that Oxford Nanopore runs, with a variety of workflows that utilize already-existing tools.
#
# In our case, we're going to be using the metagenomics workflow. This workflow allows you filter by read length and quality, filter out sequences from a host genome, detect antimicrobial resistance genes (in the case of shotgun metagenomic sequencing) and assign taxonomy to reads. There are two options for how to assign taxonomy - one is using Kraken2/Bracken, which uses kmers to map reads to the lowest common ancestor (LCA) that matches that pattern of kmers and predicts which descendant is the best match (Kraken2) and converts this into species abundances (Bracken). Below is a visualization of the Kraken workflow.
#
# The other option is mapping the reads to a provided database of specific genomes using minimap. This is useful if you know what should be in your sample already - but that's rarely the case for microbiome research.

# %% [markdown]
# ### Kraken workflow
#
# <img src="https://media.springernature.com/full/springer-static/image/art%3A10.1186%2Fgb-2014-15-3-r46/MediaObjects/13059_2013_Article_3351_Fig1_HTML.jpg?as=webp" alt="Alternative text"  width="800" height="500" />

# %% [markdown]
# ### Using Epi2me Labs

# %% [markdown]
# Epi2me Labs has a [desktop application](https://labs.epi2me.io/downloads/) that is very easy and intuitive to use. However, it's not possible to use the desktop app with the way these computing resources are set up, so we're going to use it in its command-line application (it's kind of easier to see all your options this way anyway)
#
# Epi2me workflows run using nextflow, which is a python-based method of chaining multiple programs together. It works with docker, a method of creating computing environments as packages. It's not important to know these things, but it IS important to know that I've pre-installed them here, and you will need to install them yourself if you want to run Epi2me Labs on your computer.
#
# Run the command below to see all the options for the metagenomics workflow. In this case we need to use the flag "--help" rather than "-h" as "-h" will bring up a more general menu.

# %%
nextflow run epi2me-labs/wf-metagenomics --help
# Out:
# N E X T F L O W  ~  version 23.04.3
# NOTE: Your local project version looks outdated - a different revision is available in the remote repository [4397263427]
# Launching `https://github.com/epi2me-labs/wf-metagenomics` [reverent_euclid] DSL2 - revision: 54e6d3e743 [master]
# WARN: NEXTFLOW RECURSION IS A PREVIEW FEATURE - SYNTAX AND FUNCTIONALITY CAN CHANGE IN FUTURE RELEASES
#
# ||||||||||   _____ ____ ___ ____  __  __ _____      _       _
# ||||||||||  | ____|  _ \_ _|___ \|  \/  | ____|    | | __ _| |__  ___
# |||||       |  _| | |_) | |  __) | |\/| |  _| _____| |/ _` | '_ \/ __|
# |||||       | |___|  __/| | / __/| |  | | |__|_____| | (_| | |_) \__ \
# ||||||||||  |_____|_|  |___|_____|_|  |_|_____|    |_|\__,_|_.__/|___/
# ||||||||||  wf-metagenomics v2.5.0-g54e6d3e
# --------------------------------------------------------------------------------
# Typical pipeline command:
#
#   nextflow run epi2me-labs/wf-metagenomics \
# 	--fastq 'wf-metagenomics-demo/test_data' \
# 	--threads 2
#
# Input Options
#   --fastq                       [string]  A fastq file or a directory of directories containing fastq input files.
#   --classifier                  [choice]  Kraken2 or Minimap2 workflow to be used for classification of reads. [default: kraken2]
#                                           * kraken2
#                                           * minimap2
#   --batch_size                  [integer] Maximum number of sequence records to process in a batch.
#   --analyse_unclassified        [boolean] Analyse unclassified reads from input directory. By default the workflow will not process reads in the unclassified
#                                           directory.
#   --exclude_host                [string]  A FASTA or MMI file of the host reference. Reads that align with this reference will be excluded from the
#                                           analysis.
#
# Real Time Analysis Options
#   --watch_path                  [boolean] Enable to continuously watch the input directory for new input files. Reads will be analysed as they appear
#   --read_limit                  [integer] Stop processing data when a particular number of reads have been analysed. By default the workflow will run
#                                           indefinitely.
#
# Sample Options
#   --sample_sheet                [string]  A CSV file used to map barcodes to sample aliases. The sample sheet can be provided when the input data is a directory
#                                           containing sub-directories with FASTQ files. Used only with the minimap2 classifier.
#   --sample                      [string]  A single sample name for non-multiplexed data. Permissible if passing a single .fastq(.gz) file or directory of
#                                           .fastq(.gz) files.
#
# Reference Options
#   --database_set                [choice]  Sets the reference, databases and taxonomy datasets that will be used for classifying reads. Choices:
#                                           ['ncbi_16s_18s','ncbi_16s_18s_28s_ITS', 'SILVA_138_1', 'PlusPF-8', 'PlusPFP-8']. Workflow will require memory
#                                           available to be slightly higher than the size of the database. PlusPF-8 database requires more than 8Gb. [default:
#                                           ncbi_16s_18s]
#                                           * ncbi_16s_18s
#                                           * ncbi_16s_18s_28s_ITS
#                                           * SILVA_138_1
#                                           * PlusPF-8
#                                           * PlusPFP-8
#   --database                    [string]  Not required but can be used to specifically override kraken2 database [.tar.gz or Directory].
#   --taxonomy                    [string]  Not required but can be used to specifically override taxonomy database. Change the default to use a different
#                                           taxonomy file  [.tar.gz or directory].
#   --store_dir                   [string]  Where to store initial download of database. [default: store_dir]
#   --reference                   [string]  Override the FASTA reference file selected by the database_set parameter. It can be a FASTA format reference sequence
#                                           collection or a minimap2 MMI format index.
#   --ref2taxid                   [string]  Not required but can be used to specify a  ref2taxid mapping. Format is .tsv (refname  taxid), no header row.
#   --taxonomic_rank              [choice]  Returns results at the taxonomic rank chosen. In the kraken2 pipeline: set the level that bracken will estimate
#                                           abundance at. Default: S (species). Other possible options are K (kingdom level), P (phylum), C (class), O (order), F
#                                           (family), and G (genus). [default: S]
#                                           * S
#                                           * G
#                                           * k
#                                           * F
#                                           * O
#                                           * C
#                                           * P
#
# Kraken2 Options
#   --bracken_dist                [string]  Specifically override bracken kmer dist file
#   --bracken_length              [integer] Set the length value bracken will use
#   --port                        [integer] Network port for communication between kraken2 server and clients [default: 8080]
#   --host                        [string]  Network hostname (or IP address) for communication between kraken2 server and clients. (See also 'external_kraken2'
#                                           parameter). [default: localhost]
#   --external_kraken2            [boolean] Whether a pre-existing kraken2 server should be used, rather than creating one as part of the workflow
#   --kraken2_memory_mapping      [boolean] Avoids loading database into RAM
#   --include_kraken2_assignments [boolean] A per sample TSV file that indicates how each input sequence was classified as well as the taxon that has been
#                                           assigned to each read. The TSV's will only be output on completion of the workflow and therefore not at all if using
#                                           the real time option whilst running indefinitely.
#   --kraken2_confidence          [number]  Kraken2 Confidence score threshold. Default: 0.0. Valid interval: 0-1
#
# Minimap2 Options
#   --minimap2filter              [string]  Filter output of minimap2 by taxids inc. child nodes, E.g. "9606,1404"
#   --minimap2exclude             [boolean] Invert minimap2filter and exclude the given taxids instead
#   --split_prefix                [boolean] Enable if using a very large reference with minimap2
#   --keep_bam                    [boolean] Copy bam files into the output directory.
#
# Antimicrobial Resistance Options
#   --amr                         [boolean] Scan reads for antimicrobial resistance or virulence genes
#   --amr_db                      [choice]  Database of antimicrobial resistance or virulence genes to use. [default: resfinder]
#                                           * resfinder
#                                           * ecoli_vf
#                                           * plasmidfinder
#                                           * card
#                                           * argannot
#                                           * vfdb
#                                           * ncbi
#                                           * megares
#                                           * ecoh
#   --amr_minid                   [integer] Threshold of required identity to report a match between a gene in the database and fastq reads. Valid interval:
#                                           0-100 [default: 80]
#   --amr_mincov                  [integer] Minimum coverage (breadth-of) threshold required to report a match between a gene in the  database and fastq reads.
#                                           Valid interval: 0-100 [default: 80]
#
# Report Options
#   --abundance_threshold         [number]  Remove those taxa whose abundance is lower than the chosen value.
#   --n_taxa_barplot              [integer] Number of most abundance taxa to be displayed in the barplot. The rest of taxa will be grouped under the "Other"
#                                           category. [default: 8]
#
# Output Options
#   --out_dir                     [string]  Directory for output of all user-facing files. [default: output]
#
# Advanced Options
#   --min_len                     [integer] Specify read length lower limit.
#   --min_read_qual               [number]  Specify read quality lower limit.
#   --max_len                     [integer] Specify read length upper limit
#   --threads                     [integer] Maximum number of CPU threads to use per workflow task. [default: 2]
#   --server_threads              [integer] Number of CPU threads used by the kraken2 server for classifying reads. [default: 2]
#   --kraken_clients              [integer] Number of clients that can connect at once to the kraken-server for classifying reads. [default: 2]
#
# Other parameters
#   --monochrome_logs             [boolean] null
#   --validate_params             [boolean] null [default: true]
#   --show_hidden_params          [boolean] null
#
# !! Hiding 6 params, use --show_hidden_params to show them !!
# --------------------------------------------------------------------------------
# If you use epi2me-labs/wf-metagenomics for your analysis please cite:
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x

# %% [markdown]
# Let's try running one of the mock datasets.

# %%
ls ~/data/
# Out:
# ls ~/data/
# Jessica_Zymo_DNA_16S_flongle_test  Zymo_16S_SRR25400687_Nanoplot_2
# SRR25400687_unfiltered.biom	   Zymo_16S_table.biom
# Zymo_16S_SRR25400687.fastq	   zymo_standard.csv
# Zymo_16S_SRR25400687_Nanoplot	   zymo_standard_bacteriaonly.csv
# : 1

# %% [markdown]
# Let's run the Institut Pasteur de Lille 16S dataset through Epi2me's amplicon taxonomy workflow. We'll need to provide the program with the input data (The fastq file that we input into Nanoplot), the name of a directory to store our results, and the name of the database that Epi2me (and therefore the program Kraken2 mentioned above) should use for assigning taxonomy. Since we are using 16S sequences (recall from the lectures yesterday that this is the bacterial 'barcode' gene), we should use a database of 16S sequences. We'll use the database 'ncbi_16s_18s'.

# %%
nextflow run epi2me-labs/wf-metagenomics --fastq data/Zymo_16S_SRR25400687.fastq \
    --out_dir Epi2me_results/Zymo_16S_Epi2me --database_set 'ncbi_16s_18s'
# Out:
# N E X T F L O W  ~  version 23.04.3
# NOTE: Your local project version looks outdated - a different revision is available in the remote repository [4397263427]
# Launching `https://github.com/epi2me-labs/wf-metagenomics` [modest_joliot] DSL2 - revision: 54e6d3e743 [master]
# WARN: NEXTFLOW RECURSION IS A PREVIEW FEATURE - SYNTAX AND FUNCTIONALITY CAN CHANGE IN FUTURE RELEASES
#
# ||||||||||   _____ ____ ___ ____  __  __ _____      _       _
# ||||||||||  | ____|  _ \_ _|___ \|  \/  | ____|    | | __ _| |__  ___
# |||||       |  _| | |_) | |  __) | |\/| |  _| _____| |/ _` | '_ \/ __|
# |||||       | |___|  __/| | / __/| |  | | |__|_____| | (_| | |_) \__ \
# ||||||||||  |_____|_|  |___|_____|_|  |_|_____|    |_|\__,_|_.__/|___/
# ||||||||||  wf-metagenomics v2.5.0-g54e6d3e
# --------------------------------------------------------------------------------
# Core Nextflow options
#   revision       : master
#   runName        : modest_joliot
#   containerEngine: docker
#   launchDir      : /Users/asimpson/Documents/GitHub/WSSU-Nanopore-Workshop-Fall2023
#   workDir        : /Users/asimpson/Documents/GitHub/WSSU-Nanopore-Workshop-Fall2023/work
#   projectDir     : /Users/asimpson/.nextflow/assets/epi2me-labs/wf-metagenomics
#   userName       : asimpson
#   profile        : standard
#   configFiles    : /Users/asimpson/.nextflow/assets/epi2me-labs/wf-metagenomics/nextflow.config
#
# Input Options
#   fastq          : data/Zymo_16S_SRR25400687.fastq
#
# Reference Options
#   database_sets  : [ncbi_16s_18s:[reference:https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_16s_18s.fna, refindex:https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_16s_18s.fna.fai, database:https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_kraken2.tar.gz, kmer_dist:https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/database1000mers.kmer_distrib, ref2taxid:https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ref2taxid.targloci.tsv, taxonomy:https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/taxdump_archive/taxdmp_2023-01-01.zip], ncbi_16s_18s_28s_ITS:[reference:https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s_28s_ITS/ncbi_16s_18s_28s_ITS.fna, refindex:https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s_28s_ITS/ncbi_16s_18s_28s_ITS.fna.fai, database:https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s_28s_ITS/ncbi_16s_18s_28s_ITS_kraken2.tar.gz, kmer_dist:https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s_28s_ITS/database1000mers.kmer_distrib, ref2taxid:https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s_28s_ITS/ref2taxid.ncbi_16s_18s_28s_ITS.tsv, taxonomy:https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/taxdump_archive/taxdmp_2023-01-01.zip], SILVA_138_1:[database:null], PlusPF-8:[database:https://genome-idx.s3.amazonaws.com/kraken/k2_pluspf_08gb_20230314.tar.gz, taxonomy:https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/taxdump_archive/new_taxdump_2023-03-01.zip], PlusPFP-8:[database:https://genome-idx.s3.amazonaws.com/kraken/k2_pluspfp_08gb_20230314.tar.gz, taxonomy:https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/taxdump_archive/new_taxdump_2023-03-01.zip]]
#
# Output Options
#   out_dir        : Epi2me_results/Zymo_16S_SRR25400687_Epi2me
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# --------------------------------------------------------------------------------
# If you use epi2me-labs/wf-metagenomics for your analysis please cite:
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
#
# --------------------------------------------------------------------------------
# This is epi2me-labs/wf-metagenomics v2.5.0-g54e6d3e.
# --------------------------------------------------------------------------------
# Checking inputs.
# Checking fastq input.
# [-        ] process > fastcat                        -
# [-        ] process > kraken_pipeline:unpackTaxonomy -
# [-        ] process > kraken_pipeline:unpackDatabase -
# [-        ] process > kraken_pipeline:determine_b... -
# [-        ] process > kraken_pipeline:kraken_server  -
# [-        ] process > kraken_pipeline:run_common:... -
# [-        ] process > kraken_pipeline:run_common:... -
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [-        ] process > kraken_pipeline:output         -
# [-        ] process > kraken_pipeline:stop_kraken... -
#
# executor >  local (3)
# [b7/3aed0e] process > fastcat (1)                    [  0%] 0 of 1
# [-        ] process > kraken_pipeline:unpackTaxonomy -
# [-        ] process > kraken_pipeline:unpackDatabase -
# [-        ] process > kraken_pipeline:determine_b... -
# [-        ] process > kraken_pipeline:kraken_server  -
# [38/b6e6d8] process > kraken_pipeline:run_common:... [  0%] 0 of 1
# [cf/6ae75c] process > kraken_pipeline:run_common:... [  0%] 0 of 1
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [-        ] process > kraken_pipeline:output         -
# [-        ] process > kraken_pipeline:stop_kraken... -
#
# executor >  local (3)
# [b7/3aed0e] process > fastcat (1)                    [  0%] 0 of 1
# [-        ] process > kraken_pipeline:unpackTaxonomy -
# [-        ] process > kraken_pipeline:unpackDatabase -
# [-        ] process > kraken_pipeline:determine_b... -
# [-        ] process > kraken_pipeline:kraken_server  -
# [38/b6e6d8] process > kraken_pipeline:run_common:... [  0%] 0 of 1
# [cf/6ae75c] process > kraken_pipeline:run_common:... [  0%] 0 of 1
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [-        ] process > kraken_pipeline:output         -
# [-        ] process > kraken_pipeline:stop_kraken... -
# Staging foreign file: https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/taxdump_archive/taxdmp_2023-01-01.zip
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_kraken2.tar.gz
#
# executor >  local (3)
# [b7/3aed0e] process > fastcat (1)                    [  0%] 0 of 1
# [-        ] process > kraken_pipeline:unpackTaxonomy -
# [-        ] process > kraken_pipeline:unpackDatabase -
# [-        ] process > kraken_pipeline:determine_b... -
# [-        ] process > kraken_pipeline:kraken_server  -
# [38/b6e6d8] process > kraken_pipeline:run_common:... [  0%] 0 of 1
# [cf/6ae75c] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [-        ] process > kraken_pipeline:output         [  0%] 0 of 1
# [-        ] process > kraken_pipeline:stop_kraken... -
# Staging foreign file: https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/taxdump_archive/taxdmp_2023-01-01.zip
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_kraken2.tar.gz
#
# executor >  local (4)
# [b7/3aed0e] process > fastcat (1)                    [  0%] 0 of 1
# [-        ] process > kraken_pipeline:unpackTaxonomy -
# [-        ] process > kraken_pipeline:unpackDatabase -
# [-        ] process > kraken_pipeline:determine_b... -
# [-        ] process > kraken_pipeline:kraken_server  -
# [38/b6e6d8] process > kraken_pipeline:run_common:... [  0%] 0 of 1
# [cf/6ae75c] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [d4/fe696f] process > kraken_pipeline:output (1)     [  0%] 0 of 1
# [-        ] process > kraken_pipeline:stop_kraken... -
# Staging foreign file: https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/taxdump_archive/taxdmp_2023-01-01.zip
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_kraken2.tar.gz
#
# executor >  local (4)
# [b7/3aed0e] process > fastcat (1)                    [  0%] 0 of 1
# [-        ] process > kraken_pipeline:unpackTaxonomy -
# [-        ] process > kraken_pipeline:unpackDatabase -
# [-        ] process > kraken_pipeline:determine_b... -
# [-        ] process > kraken_pipeline:kraken_server  -
# [38/b6e6d8] process > kraken_pipeline:run_common:... [  0%] 0 of 1
# [cf/6ae75c] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [d4/fe696f] process > kraken_pipeline:output (1)     [100%] 1 of 1
# [-        ] process > kraken_pipeline:stop_kraken... -
# Staging foreign file: https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/taxdump_archive/taxdmp_2023-01-01.zip
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_kraken2.tar.gz
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/database1000mers.kmer_distrib
#
# executor >  local (5)
# [b7/3aed0e] process > fastcat (1)                    [  0%] 0 of 1
# [-        ] process > kraken_pipeline:unpackTaxonomy -
# [-        ] process > kraken_pipeline:unpackDatabase -
# [-        ] process > kraken_pipeline:determine_b... -
# [-        ] process > kraken_pipeline:kraken_server  -
# [38/b6e6d8] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [cf/6ae75c] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [ca/98d128] process > kraken_pipeline:output (2)     [ 50%] 1 of 2
# [-        ] process > kraken_pipeline:stop_kraken... -
# Staging foreign file: https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/taxdump_archive/taxdmp_2023-01-01.zip
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_kraken2.tar.gz
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/database1000mers.kmer_distrib
#
# executor >  local (5)
# [b7/3aed0e] process > fastcat (1)                    [  0%] 0 of 1
# [-        ] process > kraken_pipeline:unpackTaxonomy -
# [-        ] process > kraken_pipeline:unpackDatabase -
# [-        ] process > kraken_pipeline:determine_b... -
# [-        ] process > kraken_pipeline:kraken_server  -
# [38/b6e6d8] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [cf/6ae75c] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [ca/98d128] process > kraken_pipeline:output (2)     [100%] 2 of 2
# [-        ] process > kraken_pipeline:stop_kraken... -
# Staging foreign file: https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/taxdump_archive/taxdmp_2023-01-01.zip
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_kraken2.tar.gz
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/database1000mers.kmer_distrib
#
# executor >  local (6)
# [b7/3aed0e] process > fastcat (1)                    [  0%] 0 of 1
# [-        ] process > kraken_pipeline:unpackTaxonomy -
# [b1/d5b4a4] process > kraken_pipeline:unpackDatabase [  0%] 0 of 1
# [-        ] process > kraken_pipeline:determine_b... -
# [-        ] process > kraken_pipeline:kraken_server  -
# [38/b6e6d8] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [cf/6ae75c] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [ca/98d128] process > kraken_pipeline:output (2)     [100%] 2 of 2
# [-        ] process > kraken_pipeline:stop_kraken... -
# Staging foreign file: https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/taxdump_archive/taxdmp_2023-01-01.zip
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_kraken2.tar.gz
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/database1000mers.kmer_distrib
#
# executor >  local (8)
# [b7/3aed0e] process > fastcat (1)                    [  0%] 0 of 1
# [-        ] process > kraken_pipeline:unpackTaxonomy -
# [b1/d5b4a4] process > kraken_pipeline:unpackDatabase [100%] 1 of 1 ✔
# [db/502c5c] process > kraken_pipeline:determine_b... [  0%] 0 of 1
# [e0/5937cf] process > kraken_pipeline:kraken_server  [  0%] 0 of 1
# [38/b6e6d8] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [cf/6ae75c] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [ca/98d128] process > kraken_pipeline:output (2)     [100%] 2 of 2
# [-        ] process > kraken_pipeline:stop_kraken... -
# Staging foreign file: https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/taxdump_archive/taxdmp_2023-01-01.zip
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_kraken2.tar.gz
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/database1000mers.kmer_distrib
#
# executor >  local (8)
# [b7/3aed0e] process > fastcat (1)                    [  0%] 0 of 1
# [-        ] process > kraken_pipeline:unpackTaxonomy -
# [b1/d5b4a4] process > kraken_pipeline:unpackDatabase [100%] 1 of 1 ✔
# [db/502c5c] process > kraken_pipeline:determine_b... [  0%] 0 of 1
# [e0/5937cf] process > kraken_pipeline:kraken_server  [  0%] 0 of 1
# [38/b6e6d8] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [cf/6ae75c] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [ca/98d128] process > kraken_pipeline:output (2)     [100%] 2 of 2
# [-        ] process > kraken_pipeline:stop_kraken... -
# Staging foreign file: https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/taxdump_archive/taxdmp_2023-01-01.zip
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_kraken2.tar.gz
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/database1000mers.kmer_distrib
#
# executor >  local (8)
# [b7/3aed0e] process > fastcat (1)                    [  0%] 0 of 1
# [-        ] process > kraken_pipeline:unpackTaxonomy -
# [b1/d5b4a4] process > kraken_pipeline:unpackDatabase [100%] 1 of 1 ✔
# [db/502c5c] process > kraken_pipeline:determine_b... [100%] 1 of 1 ✔
# [e0/5937cf] process > kraken_pipeline:kraken_server  [  0%] 0 of 1
# [38/b6e6d8] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [cf/6ae75c] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [ca/98d128] process > kraken_pipeline:output (2)     [100%] 2 of 2
# [-        ] process > kraken_pipeline:stop_kraken... -
# Staging foreign file: https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/taxdump_archive/taxdmp_2023-01-01.zip
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_kraken2.tar.gz
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/database1000mers.kmer_distrib
#
# executor >  local (9)
# [b7/3aed0e] process > fastcat (1)                    [  0%] 0 of 1
# [cf/cdbaa6] process > kraken_pipeline:unpackTaxonomy [  0%] 0 of 1
# [b1/d5b4a4] process > kraken_pipeline:unpackDatabase [100%] 1 of 1 ✔
# [db/502c5c] process > kraken_pipeline:determine_b... [100%] 1 of 1 ✔
# [e0/5937cf] process > kraken_pipeline:kraken_server  [  0%] 0 of 1
# [38/b6e6d8] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [cf/6ae75c] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [ca/98d128] process > kraken_pipeline:output (2)     [100%] 2 of 2
# [-        ] process > kraken_pipeline:stop_kraken... -
#
#
#
#
# executor >  local (9)
# [b7/3aed0e] process > fastcat (1)                    [  0%] 0 of 1
# [cf/cdbaa6] process > kraken_pipeline:unpackTaxonomy [100%] 1 of 1 ✔
# [b1/d5b4a4] process > kraken_pipeline:unpackDatabase [100%] 1 of 1 ✔
# [db/502c5c] process > kraken_pipeline:determine_b... [100%] 1 of 1 ✔
# [e0/5937cf] process > kraken_pipeline:kraken_server  [  0%] 0 of 1
# [38/b6e6d8] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [cf/6ae75c] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [ca/98d128] process > kraken_pipeline:output (2)     [100%] 2 of 2
# [-        ] process > kraken_pipeline:stop_kraken... -
#
#
#
#
# executor >  local (10)
# [b7/3aed0e] process > fastcat (1)                    [100%] 1 of 1 ✔
# [cf/cdbaa6] process > kraken_pipeline:unpackTaxonomy [100%] 1 of 1 ✔
# [b1/d5b4a4] process > kraken_pipeline:unpackDatabase [100%] 1 of 1 ✔
# [db/502c5c] process > kraken_pipeline:determine_b... [100%] 1 of 1 ✔
# [e0/5937cf] process > kraken_pipeline:kraken_server  [  0%] 0 of 1
# [38/b6e6d8] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [cf/6ae75c] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [3c/0138db] process > kraken_pipeline:kraken2_cli... [  0%] 0 of 1
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [ca/98d128] process > kraken_pipeline:output (2)     [100%] 2 of 2
# [-        ] process > kraken_pipeline:stop_kraken... -
#
#
# executor >  local (10)
# [b7/3aed0e] process > fastcat (1)                    [100%] 1 of 1 ✔
# [cf/cdbaa6] process > kraken_pipeline:unpackTaxonomy [100%] 1 of 1 ✔
# [b1/d5b4a4] process > kraken_pipeline:unpackDatabase [100%] 1 of 1 ✔
# [db/502c5c] process > kraken_pipeline:determine_b... [100%] 1 of 1 ✔
# [e0/5937cf] process > kraken_pipeline:kraken_server  [  0%] 0 of 1
# [38/b6e6d8] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [cf/6ae75c] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [3c/0138db] process > kraken_pipeline:kraken2_cli... [  0%] 0 of 1
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [ca/98d128] process > kraken_pipeline:output (2)     [100%] 2 of 2
# [-        ] process > kraken_pipeline:stop_kraken... -
# WARN: Killing running tasks (2)

# %% [markdown]
# Let's navigate to the results file in the file menu on the left and see what our results look like.

# %% [markdown]
# ### Quality filtering and length filtering

# %% [markdown]
# Epi2me's workflow provides some options for filtering the data by length and by the quality score of the reads. What difference does filtering by length, by quality, or both, make in terms of what species we detect?

# %% [markdown]
#   --min_len                     [integer] Specify read length lower limit.
#
#   --min_read_qual               [number]  Specify read quality lower limit.
#
#   --max_len                     [integer] Specify read length upper limit

# %% [markdown]
# #### Filtering by length
#
# We know from yesterday's discussiong that the 16S gene should be around 1,500bp. Let's try filtering the data so that the only sequences we keep are between 1,400 and 1,700 bp.

# %%
nextflow run epi2me-labs/wf-metagenomics --fastq data/Zymo_16S_SRR25400687.fastq \
    --out_dir Epi2me_results/Zymo_16S_Epi2me_lengthfiltered --database_set 'ncbi_16s_18s'\
    --min_len 1400 --max_len 1700

# %% [markdown]
# #### Filtering by quality
#
# Now let's try filtering out all the sequences with an average quality score below 14.

# %%
nextflow run epi2me-labs/wf-metagenomics --fastq data/Zymo_16S_SRR25400687.fastq \
    --out_dir Epi2me_results/Zymo_16S_Epi2me_qualityfiltered --database_set 'ncbi_16s_18s'\
    --min_read_qual 14

# %% [markdown]
# #### Filtering by both

# %%
nextflow run epi2me-labs/wf-metagenomics --fastq data/Zymo_16S_SRR25400687.fastq \
    --out_dir Epi2me_results/Zymo_16S_Epi2me_qualityandlengthfiltered --database_set 'ncbi_16s_18s'\
    --min_len 1400 --max_len 1700--min_read_qual 14
# Out:
# nextflow run epi2me-labs/wf-metagenomics --fastq ~/data/Zymo_16S_SRR25400687.fastq \
#     --out_dir ~/backup/Zymo_16S_SRR25400687_Epi2me_filtered --database_set 'ncbi_16s_18s'\
#     --min_len 1390 --max_len 1780 --min_read_qual 14
# N E X T F L O W  ~  version 23.04.3
# Launching `https://github.com/epi2me-labs/wf-metagenomics` [astonishing_hodgkin] DSL2 - revision: 54e6d3e743 [master]
# WARN: NEXTFLOW RECURSION IS A PREVIEW FEATURE - SYNTAX AND FUNCTIONALITY CAN CHANGE IN FUTURE RELEASES
#
# ||||||||||   _____ ____ ___ ____  __  __ _____      _       _
# ||||||||||  | ____|  _ \_ _|___ \|  \/  | ____|    | | __ _| |__  ___
# |||||       |  _| | |_) | |  __) | |\/| |  _| _____| |/ _` | '_ \/ __|
# |||||       | |___|  __/| | / __/| |  | | |__|_____| | (_| | |_) \__ \
# ||||||||||  |_____|_|  |___|_____|_|  |_|_____|    |_|\__,_|_.__/|___/
# ||||||||||  wf-metagenomics v2.5.0-g54e6d3e
# --------------------------------------------------------------------------------
# Core Nextflow options
#   revision       : master
#   runName        : astonishing_hodgkin
#   containerEngine: docker
#   launchDir      : /home/gl4u/Notebooks
#   workDir        : /home/gl4u/Notebooks/work
#   projectDir     : /home/gl4u/.nextflow/assets/epi2me-labs/wf-metagenomics
#   userName       : gl4u
#   profile        : standard
#   configFiles    : /home/gl4u/.nextflow/assets/epi2me-labs/wf-metagenomics/nextflow.config
#
# Input Options
#   fastq          : /home/gl4u/data/Zymo_16S_SRR25400687.fastq
#
# Reference Options
#   database_sets  : [ncbi_16s_18s:[reference:https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_16s_18s.fna, refindex:https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_16s_18s.fna.fai, database:https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_kraken2.tar.gz, kmer_dist:https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/database1000mers.kmer_distrib, ref2taxid:https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ref2taxid.targloci.tsv, taxonomy:https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/taxdump_archive/taxdmp_2023-01-01.zip], ncbi_16s_18s_28s_ITS:[reference:https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s_28s_ITS/ncbi_16s_18s_28s_ITS.fna, refindex:https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s_28s_ITS/ncbi_16s_18s_28s_ITS.fna.fai, database:https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s_28s_ITS/ncbi_16s_18s_28s_ITS_kraken2.tar.gz, kmer_dist:https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s_28s_ITS/database1000mers.kmer_distrib, ref2taxid:https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s_28s_ITS/ref2taxid.ncbi_16s_18s_28s_ITS.tsv, taxonomy:https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/taxdump_archive/taxdmp_2023-01-01.zip], SILVA_138_1:[database:null], PlusPF-8:[database:https://genome-idx.s3.amazonaws.com/kraken/k2_pluspf_08gb_20230314.tar.gz, taxonomy:https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/taxdump_archive/new_taxdump_2023-03-01.zip], PlusPFP-8:[database:https://genome-idx.s3.amazonaws.com/kraken/k2_pluspfp_08gb_20230314.tar.gz, taxonomy:https://ftp.ncbi.nlm.nih.gov/pub/taxonomy/taxdump_archive/new_taxdump_2023-03-01.zip]]
#
# Output Options
#   out_dir        : /home/gl4u/backup/Zymo_16S_SRR25400687_Epi2me_filtered
#
# Advanced Options
#   min_len        : 1390
#   min_read_qual  : 14
#   max_len        : 1780
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# --------------------------------------------------------------------------------
# If you use epi2me-labs/wf-metagenomics for your analysis please cite:
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
#
# --------------------------------------------------------------------------------
# This is epi2me-labs/wf-metagenomics v2.5.0-g54e6d3e.
# --------------------------------------------------------------------------------
# Checking inputs.
# Checking fastq input.
# [-        ] process > fastcat -
#
# executor >  local (1)
# [-        ] process > fastcat                        [  0%] 0 of 1
# [-        ] process > kraken_pipeline:unpackTaxonomy -
# [-        ] process > kraken_pipeline:unpackDatabase -
# [-        ] process > kraken_pipeline:determine_b... -
# [-        ] process > kraken_pipeline:kraken_server  -
# [de/5e770b] process > kraken_pipeline:run_common:... [  0%] 0 of 1
# [-        ] process > kraken_pipeline:run_common:... [  0%] 0 of 1
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [-        ] process > kraken_pipeline:output         -
# [-        ] process > kraken_pipeline:stop_kraken... -
#
# executor >  local (3)
# [cb/761cce] process > fastcat (1)                    [  0%] 0 of 1
# [-        ] process > kraken_pipeline:unpackTaxonomy -
# [-        ] process > kraken_pipeline:unpackDatabase -
# [-        ] process > kraken_pipeline:determine_b... -
# [-        ] process > kraken_pipeline:kraken_server  -
# [de/5e770b] process > kraken_pipeline:run_common:... [  0%] 0 of 1
# [42/840b41] process > kraken_pipeline:run_common:... [  0%] 0 of 1
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [-        ] process > kraken_pipeline:output         -
# [-        ] process > kraken_pipeline:stop_kraken... -
#
# executor >  local (4)
# [cb/761cce] process > fastcat (1)                    [  0%] 0 of 1
# [-        ] process > kraken_pipeline:unpackTaxonomy -
# [-        ] process > kraken_pipeline:unpackDatabase -
# [-        ] process > kraken_pipeline:determine_b... -
# [-        ] process > kraken_pipeline:kraken_server  -
# [de/5e770b] process > kraken_pipeline:run_common:... [  0%] 0 of 1
# [42/840b41] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [90/28329c] process > kraken_pipeline:output (1)     [  0%] 0 of 1
# [-        ] process > kraken_pipeline:stop_kraken... -
#
# executor >  local (4)
# [cb/761cce] process > fastcat (1)                    [  0%] 0 of 1
# [-        ] process > kraken_pipeline:unpackTaxonomy -
# [-        ] process > kraken_pipeline:unpackDatabase -
# [-        ] process > kraken_pipeline:determine_b... -
# [-        ] process > kraken_pipeline:kraken_server  -
# [de/5e770b] process > kraken_pipeline:run_common:... [  0%] 0 of 1
# [42/840b41] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [90/28329c] process > kraken_pipeline:output (1)     [100%] 1 of 1
# [-        ] process > kraken_pipeline:stop_kraken... -
#
# executor >  local (4)
# [cb/761cce] process > fastcat (1)                    [  0%] 0 of 1
# [skipped  ] process > kraken_pipeline:unpackTaxonomy [100%] 1 of 1, stored: 1 ✔
# [-        ] process > kraken_pipeline:unpackDatabase -
# [-        ] process > kraken_pipeline:determine_b... -
# [-        ] process > kraken_pipeline:kraken_server  -
# [de/5e770b] process > kraken_pipeline:run_common:... [  0%] 0 of 1
# [42/840b41] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [90/28329c] process > kraken_pipeline:output (1)     [100%] 1 of 1
# [-        ] process > kraken_pipeline:stop_kraken... -
# [skipping] Stored process > kraken_pipeline:unpackTaxonomy
#
# executor >  local (5)
# [cb/761cce] process > fastcat (1)                    [  0%] 0 of 1
# [skipped  ] process > kraken_pipeline:unpackTaxonomy [100%] 1 of 1, stored: 1 ✔
# [-        ] process > kraken_pipeline:unpackDatabase -
# [-        ] process > kraken_pipeline:determine_b... -
# [-        ] process > kraken_pipeline:kraken_server  -
# [de/5e770b] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [42/840b41] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [39/9237bb] process > kraken_pipeline:output (2)     [ 50%] 1 of 2
# [-        ] process > kraken_pipeline:stop_kraken... -
# [skipping] Stored process > kraken_pipeline:unpackTaxonomy
#
# executor >  local (5)
# [cb/761cce] process > fastcat (1)                    [  0%] 0 of 1
# [skipped  ] process > kraken_pipeline:unpackTaxonomy [100%] 1 of 1, stored: 1 ✔
# [-        ] process > kraken_pipeline:unpackDatabase -
# [-        ] process > kraken_pipeline:determine_b... -
# [-        ] process > kraken_pipeline:kraken_server  -
# [de/5e770b] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [42/840b41] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [39/9237bb] process > kraken_pipeline:output (2)     [ 50%] 1 of 2
# [-        ] process > kraken_pipeline:stop_kraken... -
# [skipping] Stored process > kraken_pipeline:unpackTaxonomy
#
# executor >  local (5)
# [cb/761cce] process > fastcat (1)                    [  0%] 0 of 1
# [skipped  ] process > kraken_pipeline:unpackTaxonomy [100%] 1 of 1, stored: 1 ✔
# [-        ] process > kraken_pipeline:unpackDatabase -
# [-        ] process > kraken_pipeline:determine_b... -
# [-        ] process > kraken_pipeline:kraken_server  -
# [de/5e770b] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [42/840b41] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [39/9237bb] process > kraken_pipeline:output (2)     [100%] 2 of 2
# [-        ] process > kraken_pipeline:stop_kraken... -
# [skipping] Stored process > kraken_pipeline:unpackTaxonomy
#
# executor >  local (5)
# [cb/761cce] process > fastcat (1)                    [  0%] 0 of 1
# [skipped  ] process > kraken_pipeline:unpackTaxonomy [100%] 1 of 1, stored: 1 ✔
# [-        ] process > kraken_pipeline:unpackDatabase -
# [-        ] process > kraken_pipeline:determine_b... -
# [-        ] process > kraken_pipeline:kraken_server  -
# [de/5e770b] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [42/840b41] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [39/9237bb] process > kraken_pipeline:output (2)     [100%] 2 of 2
# [-        ] process > kraken_pipeline:stop_kraken... -
# [skipping] Stored process > kraken_pipeline:unpackTaxonomy
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_kraken2.tar.gz
#
# executor >  local (7)
# [cb/761cce] process > fastcat (1)                    [  0%] 0 of 1
# [skipped  ] process > kraken_pipeline:unpackTaxonomy [100%] 1 of 1, stored: 1 ✔
# [skipped  ] process > kraken_pipeline:unpackDatabase [100%] 1 of 1, stored: 1 ✔
# [3c/fd30ed] process > kraken_pipeline:determine_b... [  0%] 0 of 1
# [39/13390a] process > kraken_pipeline:kraken_server  [  0%] 0 of 1
# [de/5e770b] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [42/840b41] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [39/9237bb] process > kraken_pipeline:output (2)     [100%] 2 of 2
# [-        ] process > kraken_pipeline:stop_kraken... -
# [skipping] Stored process > kraken_pipeline:unpackTaxonomy
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_kraken2.tar.gz
# [skipping] Stored process > kraken_pipeline:unpackDatabase
#
# executor >  local (7)
# [cb/761cce] process > fastcat (1)                    [  0%] 0 of 1
# [skipped  ] process > kraken_pipeline:unpackTaxonomy [100%] 1 of 1, stored: 1 ✔
# [skipped  ] process > kraken_pipeline:unpackDatabase [100%] 1 of 1, stored: 1 ✔
# [3c/fd30ed] process > kraken_pipeline:determine_b... [  0%] 0 of 1
# [39/13390a] process > kraken_pipeline:kraken_server  [  0%] 0 of 1
# [de/5e770b] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [42/840b41] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [39/9237bb] process > kraken_pipeline:output (2)     [100%] 2 of 2
# [-        ] process > kraken_pipeline:stop_kraken... -
# [skipping] Stored process > kraken_pipeline:unpackTaxonomy
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_kraken2.tar.gz
# [skipping] Stored process > kraken_pipeline:unpackDatabase
#
# executor >  local (7)
# [cb/761cce] process > fastcat (1)                    [  0%] 0 of 1
# [skipped  ] process > kraken_pipeline:unpackTaxonomy [100%] 1 of 1, stored: 1 ✔
# [skipped  ] process > kraken_pipeline:unpackDatabase [100%] 1 of 1, stored: 1 ✔
# [3c/fd30ed] process > kraken_pipeline:determine_b... [100%] 1 of 1 ✔
# [39/13390a] process > kraken_pipeline:kraken_server  [  0%] 0 of 1
# [de/5e770b] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [42/840b41] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [-        ] process > kraken_pipeline:kraken2_client -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [39/9237bb] process > kraken_pipeline:output (2)     [100%] 2 of 2
# [-        ] process > kraken_pipeline:stop_kraken... -
# [skipping] Stored process > kraken_pipeline:unpackTaxonomy
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_kraken2.tar.gz
# [skipping] Stored process > kraken_pipeline:unpackDatabase
#
# executor >  local (8)
# [cb/761cce] process > fastcat (1)                    [100%] 1 of 1 ✔
# [skipped  ] process > kraken_pipeline:unpackTaxonomy [100%] 1 of 1, stored: 1 ✔
# [skipped  ] process > kraken_pipeline:unpackDatabase [100%] 1 of 1, stored: 1 ✔
# [3c/fd30ed] process > kraken_pipeline:determine_b... [100%] 1 of 1 ✔
# [39/13390a] process > kraken_pipeline:kraken_server  [  0%] 0 of 1
# [de/5e770b] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [42/840b41] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [1b/9bf636] process > kraken_pipeline:kraken2_cli... [  0%] 0 of 1
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [39/9237bb] process > kraken_pipeline:output (2)     [100%] 2 of 2
# [-        ] process > kraken_pipeline:stop_kraken... -
# [skipping] Stored process > kraken_pipeline:unpackTaxonomy
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_kraken2.tar.gz
# [skipping] Stored process > kraken_pipeline:unpackDatabase
#
# executor >  local (11)
# [cb/761cce] process > fastcat (1)                    [100%] 1 of 1 ✔
# [skipped  ] process > kraken_pipeline:unpackTaxonomy [100%] 1 of 1, stored: 1 ✔
# [skipped  ] process > kraken_pipeline:unpackDatabase [100%] 1 of 1, stored: 1 ✔
# [3c/fd30ed] process > kraken_pipeline:determine_b... [100%] 1 of 1 ✔
# [39/13390a] process > kraken_pipeline:kraken_server  [  0%] 0 of 1
# [de/5e770b] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [42/840b41] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [1b/9bf636] process > kraken_pipeline:kraken2_cli... [100%] 1 of 1 ✔
# [34/dab171] process > kraken_pipeline:progressive... [  0%] 0 of 1
# [29/913b52] process > kraken_pipeline:progressive... [  0%] 0 of 1
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [39/9237bb] process > kraken_pipeline:output (2)     [100%] 2 of 2
# [ea/327b5d] process > kraken_pipeline:stop_kraken... [  0%] 0 of 1
# [skipping] Stored process > kraken_pipeline:unpackTaxonomy
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_kraken2.tar.gz
# [skipping] Stored process > kraken_pipeline:unpackDatabase
#
# executor >  local (11)
# [cb/761cce] process > fastcat (1)                    [100%] 1 of 1 ✔
# [skipped  ] process > kraken_pipeline:unpackTaxonomy [100%] 1 of 1, stored: 1 ✔
# [skipped  ] process > kraken_pipeline:unpackDatabase [100%] 1 of 1, stored: 1 ✔
# [3c/fd30ed] process > kraken_pipeline:determine_b... [100%] 1 of 1 ✔
# [39/13390a] process > kraken_pipeline:kraken_server  [  0%] 0 of 1
# [de/5e770b] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [42/840b41] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [1b/9bf636] process > kraken_pipeline:kraken2_cli... [100%] 1 of 1 ✔
# [34/dab171] process > kraken_pipeline:progressive... [  0%] 0 of 1
# [29/913b52] process > kraken_pipeline:progressive... [  0%] 0 of 1
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [39/9237bb] process > kraken_pipeline:output (2)     [100%] 2 of 2
# [ea/327b5d] process > kraken_pipeline:stop_kraken... [  0%] 0 of 1
# [skipping] Stored process > kraken_pipeline:unpackTaxonomy
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_kraken2.tar.gz
# [skipping] Stored process > kraken_pipeline:unpackDatabase
#
# executor >  local (11)
# [cb/761cce] process > fastcat (1)                    [100%] 1 of 1 ✔
# [skipped  ] process > kraken_pipeline:unpackTaxonomy [100%] 1 of 1, stored: 1 ✔
# [skipped  ] process > kraken_pipeline:unpackDatabase [100%] 1 of 1, stored: 1 ✔
# [3c/fd30ed] process > kraken_pipeline:determine_b... [100%] 1 of 1 ✔
# [39/13390a] process > kraken_pipeline:kraken_server  [100%] 1 of 1 ✔
# [de/5e770b] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [42/840b41] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [1b/9bf636] process > kraken_pipeline:kraken2_cli... [100%] 1 of 1 ✔
# [34/dab171] process > kraken_pipeline:progressive... [  0%] 0 of 1
# [29/913b52] process > kraken_pipeline:progressive... [  0%] 0 of 1
# [-        ] process > kraken_pipeline:progressive... -
# [-        ] process > kraken_pipeline:makeReport     -
# [39/9237bb] process > kraken_pipeline:output (2)     [100%] 2 of 2
# [ea/327b5d] process > kraken_pipeline:stop_kraken... [100%] 1 of 1 ✔
# [skipping] Stored process > kraken_pipeline:unpackTaxonomy
# Staging foreign file: https://ont-exd-int-s3-euwst1-epi2me-labs.s3.amazonaws.com/wf-metagenomics/ncbi_16s_18s/ncbi_targeted_loci_kraken2.tar.gz
# [skipping] Stored process > kraken_pipeline:unpackDatabase
#
# executor >  local (12)
# [cb/761cce] process > fastcat (1)                    [100%] 1 of 1 ✔
# [skipped  ] process > kraken_pipeline:unpackTaxonomy [100%] 1 of 1, stored: 1 ✔
# [skipped  ] process > kraken_pipeline:unpackDatabase [100%] 1 of 1, stored: 1 ✔
# [3c/fd30ed] process > kraken_pipeline:determine_b... [100%] 1 of 1 ✔
# [39/13390a] process > kraken_pipeline:kraken_server  [100%] 1 of 1 ✔
# [de/5e770b] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [42/840b41] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [1b/9bf636] process > kraken_pipeline:kraken2_cli... [100%] 1 of 1 ✔
# [34/dab171] process > kraken_pipeline:progressive... [100%] 1 of 1 ✔
# [29/913b52] process > kraken_pipeline:progressive... [100%] 1 of 1 ✔
# [d6/2fd230] process > kraken_pipeline:progressive... [  0%] 0 of 1
# [-        ] process > kraken_pipeline:makeReport     -
# [39/9237bb] process > kraken_pipeline:output (2)     [100%] 2 of 2
# [ea/327b5d] process > kraken_pipeline:stop_kraken... [100%] 1 of 1 ✔
#
#
#
#
# executor >  local (12)
# [cb/761cce] process > fastcat (1)                    [100%] 1 of 1 ✔
# [skipped  ] process > kraken_pipeline:unpackTaxonomy [100%] 1 of 1, stored: 1 ✔
# [skipped  ] process > kraken_pipeline:unpackDatabase [100%] 1 of 1, stored: 1 ✔
# [3c/fd30ed] process > kraken_pipeline:determine_b... [100%] 1 of 1 ✔
# [39/13390a] process > kraken_pipeline:kraken_server  [100%] 1 of 1 ✔
# [de/5e770b] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [42/840b41] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [1b/9bf636] process > kraken_pipeline:kraken2_cli... [100%] 1 of 1 ✔
# [34/dab171] process > kraken_pipeline:progressive... [100%] 1 of 1 ✔
# [29/913b52] process > kraken_pipeline:progressive... [100%] 1 of 1 ✔
# [d6/2fd230] process > kraken_pipeline:progressive... [  0%] 0 of 1 ✔
# [-        ] process > kraken_pipeline:makeReport     -
# [39/9237bb] process > kraken_pipeline:output (2)     [100%] 2 of 2
# [ea/327b5d] process > kraken_pipeline:stop_kraken... [100%] 1 of 1 ✔
#
#
#
#
# executor >  local (13)
# [cb/761cce] process > fastcat (1)                    [100%] 1 of 1 ✔
# [skipped  ] process > kraken_pipeline:unpackTaxonomy [100%] 1 of 1, stored: 1 ✔
# [skipped  ] process > kraken_pipeline:unpackDatabase [100%] 1 of 1, stored: 1 ✔
# [3c/fd30ed] process > kraken_pipeline:determine_b... [100%] 1 of 1 ✔
# [39/13390a] process > kraken_pipeline:kraken_server  [100%] 1 of 1 ✔
# [de/5e770b] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [42/840b41] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [1b/9bf636] process > kraken_pipeline:kraken2_cli... [100%] 1 of 1 ✔
# [34/dab171] process > kraken_pipeline:progressive... [100%] 1 of 1 ✔
# [29/913b52] process > kraken_pipeline:progressive... [100%] 1 of 1 ✔
# [d6/2fd230] process > kraken_pipeline:progressive... [100%] 1 of 1 ✔
# [6f/a4fb78] process > kraken_pipeline:makeReport (1) [  0%] 0 of 1
# [39/9237bb] process > kraken_pipeline:output (2)     [100%] 2 of 2
# [ea/327b5d] process > kraken_pipeline:stop_kraken... [100%] 1 of 1 ✔
#
# executor >  local (14)
# [cb/761cce] process > fastcat (1)                    [100%] 1 of 1 ✔
# [skipped  ] process > kraken_pipeline:unpackTaxonomy [100%] 1 of 1, stored: 1 ✔
# [skipped  ] process > kraken_pipeline:unpackDatabase [100%] 1 of 1, stored: 1 ✔
# [3c/fd30ed] process > kraken_pipeline:determine_b... [100%] 1 of 1 ✔
# [39/13390a] process > kraken_pipeline:kraken_server  [100%] 1 of 1 ✔
# [de/5e770b] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [42/840b41] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [1b/9bf636] process > kraken_pipeline:kraken2_cli... [100%] 1 of 1 ✔
# [34/dab171] process > kraken_pipeline:progressive... [100%] 1 of 1 ✔
# [29/913b52] process > kraken_pipeline:progressive... [100%] 1 of 1 ✔
# [d6/2fd230] process > kraken_pipeline:progressive... [100%] 1 of 1 ✔
# [6f/a4fb78] process > kraken_pipeline:makeReport (1) [100%] 1 of 1 ✔
# [d7/426c5a] process > kraken_pipeline:output (3)     [ 66%] 2 of 3
# [ea/327b5d] process > kraken_pipeline:stop_kraken... [100%] 1 of 1 ✔
#
# executor >  local (14)
# [cb/761cce] process > fastcat (1)                    [100%] 1 of 1 ✔
# [skipped  ] process > kraken_pipeline:unpackTaxonomy [100%] 1 of 1, stored: 1 ✔
# [skipped  ] process > kraken_pipeline:unpackDatabase [100%] 1 of 1, stored: 1 ✔
# [3c/fd30ed] process > kraken_pipeline:determine_b... [100%] 1 of 1 ✔
# [39/13390a] process > kraken_pipeline:kraken_server  [100%] 1 of 1 ✔
# [de/5e770b] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [42/840b41] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [1b/9bf636] process > kraken_pipeline:kraken2_cli... [100%] 1 of 1 ✔
# [34/dab171] process > kraken_pipeline:progressive... [100%] 1 of 1 ✔
# [29/913b52] process > kraken_pipeline:progressive... [100%] 1 of 1 ✔
# [d6/2fd230] process > kraken_pipeline:progressive... [100%] 1 of 1 ✔
# [6f/a4fb78] process > kraken_pipeline:makeReport (1) [100%] 1 of 1 ✔
# [d7/426c5a] process > kraken_pipeline:output (3)     [100%] 3 of 3 ✔
# [ea/327b5d] process > kraken_pipeline:stop_kraken... [100%] 1 of 1 ✔
#
# executor >  local (14)
# [cb/761cce] process > fastcat (1)                    [100%] 1 of 1 ✔
# [skipped  ] process > kraken_pipeline:unpackTaxonomy [100%] 1 of 1, stored: 1 ✔
# [skipped  ] process > kraken_pipeline:unpackDatabase [100%] 1 of 1, stored: 1 ✔
# [3c/fd30ed] process > kraken_pipeline:determine_b... [100%] 1 of 1 ✔
# [39/13390a] process > kraken_pipeline:kraken_server  [100%] 1 of 1 ✔
# [de/5e770b] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [42/840b41] process > kraken_pipeline:run_common:... [100%] 1 of 1 ✔
# [1b/9bf636] process > kraken_pipeline:kraken2_cli... [100%] 1 of 1 ✔
# [34/dab171] process > kraken_pipeline:progressive... [100%] 1 of 1 ✔
# [29/913b52] process > kraken_pipeline:progressive... [100%] 1 of 1 ✔
# [d6/2fd230] process > kraken_pipeline:progressive... [100%] 1 of 1 ✔
# [6f/a4fb78] process > kraken_pipeline:makeReport (1) [100%] 1 of 1 ✔
# [d7/426c5a] process > kraken_pipeline:output (3)     [100%] 3 of 3 ✔
# [ea/327b5d] process > kraken_pipeline:stop_kraken... [100%] 1 of 1 ✔
# Completed at: 10-Sep-2023 11:11:27
# Duration    : 1m 32s
# CPU hours   : 0.1
# Succeeded   : 14
# : 1

# %% [markdown]
# Now try your own way of filtering the data! Call the result file "Epi2me_results/Zymo_16S_Epi2me_myfilter"

# %% [markdown]
# Let's navigate to the left-hand menu and look at the resulting file reports together.
